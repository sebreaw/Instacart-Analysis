# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/sebreawilmore/Instacart Basket Analysis'

# %%
df_main = pd.read_pickle(r'/Users/sebreawilmore/Instacart Basket Analysis/Data/orders_products_combined.pkl')

# %%
df_main.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0           1.0                 2.0                8.0
# 1  2398795.0      1.0           2.0                 3.0                7.0
# 2   473747.0      1.0           3.0                 3.0               12.0
# 3  2254736.0      1.0           4.0                 4.0                7.0
# 4   431534.0      1.0           5.0                 4.0               15.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN       196.0                1.0        0.0
# 1                    15.0       196.0                1.0        1.0
# 2                    21.0       196.0                1.0        1.0
# 3                    29.0       196.0                1.0        1.0
# 4                    28.0       196.0                1.0        1.0
#
#    Unnamed: 0_y  ...    price_range_loc      busiest_day  \
# ...

# %%
#Subset
df = df_main[:1000000]

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
#Applying function
df.loc['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/2t/p_g0nbhj1xx4cv4_8gwmkjm00000gn/T/ipykernel_4022/4089919816.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc['price_range'] = df.apply(price_label, axis=1)

# %%
df.head()

# %%
#Product Type Count
df['price_range'].value_counts(dropna = False)

# %%
df['prices'].max()

# %% [markdown]
# # Applying If Statement To Entire Data Set

# %%
df = pd.read_pickle(r'/Users/sebreawilmore/Instacart Basket Analysis/Data/orders_products_combined.pkl')

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# NaN                          1
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # <center>Task 4.7</center>

# %% [markdown]
# # 1.

# %%
orders_products_merge = pd.read_pickle(r'/Users/sebreawilmore/Instacart Basket Analysis/Data/orders_products_combined.pkl')

# %%
orders_products_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0.0    6204182
# 1.0    5660230
# 6.0    4496490
# 2.0    4213830
# 5.0    4205791
# 3.0    3840534
# 4.0    3783802
# NaN          1
# Name: orders_day_of_week, dtype: int64

# %%
result = []

for value in orders_products_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
orders_products_merge['busiest_day'] = result

# %%
orders_products_merge.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0           1.0                 2.0                8.0
# 1  2398795.0      1.0           2.0                 3.0                7.0
# 2   473747.0      1.0           3.0                 3.0               12.0
# 3  2254736.0      1.0           4.0                 4.0                7.0
# 4   431534.0      1.0           5.0                 4.0               15.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN       196.0                1.0        0.0
# 1                    15.0       196.0                1.0        1.0
# 2                    21.0       196.0                1.0        1.0
# 3                    29.0       196.0                1.0        1.0
# 4                    28.0       196.0                1.0        1.0
#
#    Unnamed: 0_y  ...    price_range_loc     busiest_day  \
# ...

# %%
orders_products_merge['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416876
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %% [markdown]
# # 2.

# %%
#Drop 'Busiest Day column'

orders_products_merge = orders_products_merge.drop(columns = ['busiest_day'])

# %%
orders_products_merge.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0           1.0                 2.0                8.0
# 1  2398795.0      1.0           2.0                 3.0                7.0
# 2   473747.0      1.0           3.0                 3.0               12.0
# 3  2254736.0      1.0           4.0                 4.0                7.0
# 4   431534.0      1.0           5.0                 4.0               15.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN       196.0                1.0        0.0
# 1                    15.0       196.0                1.0        1.0
# 2                    21.0       196.0                1.0        1.0
# 3                    29.0       196.0                1.0        1.0
# 4                    28.0       196.0                1.0        1.0
#
#    Unnamed: 0_y  ... prices    price_range_loc  busiest_period_of_day  \
# ...

# %%
#Adding column for busiest and slowest days
results = []

for value in orders_products_merge["orders_day_of_week"]:
  if value == 0 or value == 1:
    results.append("Busiest days")
  elif value == 4 or value == 3:
    results.append("Least busy days")
  else:
    results.append("Regularly busy")

# %% [markdown]
# Note:
# Saturday is the busiest day, Sunday is the second busiest day
# Wednesday is the slowest day, Tuesday is the second slowest day

# %%
orders_products_merge['busiest_day'] = results

# %%
orders_products_merge['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy     12916112
# Busiest days       11864412
# Least busy days     7624336
# Name: busiest_day, dtype: int64

# %% [markdown]
# # 3.
# When compared to the original counts, these values equal the sum of each grouping (Busiest days, Least busy days), indicating that the loop performed accurately.

# %% [markdown]
# # 4.

# %%
orders_products_merge['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10.0    2761760
# 11.0    2736140
# 14.0    2689136
# 15.0    2662144
# 13.0    2660954
# 12.0    2618532
# 16.0    2535202
# 9.0     2454203
# 17.0    2087654
# 8.0     1718118
# 18.0    1636502
# 19.0    1258305
# 20.0     976156
# 7.0      891054
# 21.0     795637
# 22.0     634225
# 23.0     402316
# 6.0      290493
# 0.0      218769
# 1.0      115700
# 5.0       87961
# 2.0       69375
# 4.0       53242
# 3.0       51281
# NaN           1
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# The grouping for each segment will be as follows:
# Most orders - 10,11,14,15,13,12,16,9
# Average orders - 17, 8, 18, 19, 20, 7, 21, 22
# Fewest orders - 23, 6, 0, 1, 5, 2, 4, 3

# %%
#Creating For Loop If Statement Using The Above Conditions
hour_of_day = []

for value in orders_products_merge["order_hour_of_day"]:
  if value in [10, 11, 14, 15, 13, 12, 16, 9]:
    hour_of_day.append("Most orders")
  elif value in [23, 6, 0, 1, 5, 2, 4, 3]:
    hour_of_day.append("Fewest orders")
  else:
    hour_of_day.append("Average orders")

# %%
#Applying results to dataframe 
orders_products_merge['busiest_period_of_day'] = hour_of_day

# %%
orders_products_merge.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0           1.0                 2.0                8.0
# 1  2398795.0      1.0           2.0                 3.0                7.0
# 2   473747.0      1.0           3.0                 3.0               12.0
# 3  2254736.0      1.0           4.0                 4.0                7.0
# 4   431534.0      1.0           5.0                 4.0               15.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN       196.0                1.0        0.0
# 1                    15.0       196.0                1.0        1.0
# 2                    21.0       196.0                1.0        1.0
# 3                    29.0       196.0                1.0        1.0
# 4                    28.0       196.0                1.0        1.0
#
#    Unnamed: 0_y  ...    price_range_loc  busiest_period_of_day  max_order  \
# ...

# %% [markdown]
# # 5.

# %%
orders_products_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       21118071
# Average orders     9997652
# Fewest orders      1289137
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# Values in each column match the sum of the ungrouped frequencies

# %% [markdown]
# # Exporting Dataframe

# %%
orders_products_merge.to_pickle(os.path.join(path, 'Data', 'orders_products_combined.pkl'))
